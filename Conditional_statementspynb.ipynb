# %% [markdown]
# <a href="https://colab.research.google.com/github/AnopaMunemo/Coding-Projects-/blob/main/Conditional_statementspynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if True :
  print('Whats up')
# Out:
# Whats up

# %%
applicant_skill='SQL'
job_skill='SQL'

# %%
if job_skill==applicant_skill:
    print('skills Match!')
# Out:
# skills Match!

# %%
job_skill='SQL'
applicant_skill='Python'
year_experience = 3

if job_skill == applicant_skill:
  print('skills Match!')
elif year_experience >= 5:
  print('Enough Experience ; No SQL')
elif applicant_skill == 'Python':
  print('Applicant knows Python')
  pass
else:
  print('No skill or experience ')
# Out:
# Applicant knows Python
