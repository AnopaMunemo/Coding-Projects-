# %% [markdown]
# <a href="https://colab.research.google.com/github/AnopaMunemo/Coding-Projects-/blob/main/lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
job_skills = ['sql', 'tableau','excel']

# %%
job_skills.append('python')

# %%
job_skills.remove('excel')

# %%
job_skills
# Out:
# ['sql', 'tableau', 'python']

# %%
job_skills[1]
# Out:
# 'tableau'

# %%
job_skills.insert(2,'excel')

# %%
job_skills
# Out:
# ['sql', 'tableau', 'excel', 'python']

# %%
job_skills.pop(2)
# Out:
# 'excel'

# %%
job_skills
# Out:
# ['sql', 'tableau', 'python']

# %%
job_skills[0:2]
# Out:
# ['sql', 'tableau']

# %%
job_skills[:
          ]
# Out:
# ['sql', 'tableau', 'python']

# %%
luke_skills=['python','bigquery','r']
kelly_skills= ['python','sql','looker']

all_skills= luke_skills+ kelly_skills

all_skills
# Out:
# ['python', 'bigquery', 'r', 'python', 'sql', 'looker']

# %%
all_skills[::2]
# Out:
# ['python', 'r', 'sql']

# %%
all_skills[-1]
# Out:
# 'looker'

# %%
job_skills.sort()
job_skills
# Out:
# ['python', 'sql', 'tableau']

# %%
job_skills=['python','excel','sql','looker']

# %%
skill1,skill2,skill3,skill4= job_skills

# %%
print(skill1)
print(skill2)
print(skill3)
# Out:
# python
# excel
# sql
