# %% [markdown]
# <a href="https://colab.research.google.com/github/AnopaMunemo/Coding-Projects-/blob/main/Basics%20(method)" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data types

# %%
total_salary=110000
bonus_salary=10000

# %%
type(total_salary)
# Out:
# int

# %%
base_salary=total_salary-bonus_salary

# %%
base_salary
# Out:
# 100000

# %%
job_title='Data Analyst'
remove_word='Data'

# %%
type(job_title )
# Out:
# str

# %%
' Data ' + ' science '
# Out:
# ' Data  science '

# %%
'Data Science'.capitalize
# Out:
# <function str.capitalize()>

# %%
job_id=102

# %%
type(job_id)
# Out:
# int

# %%
job_id=float(102)

# %%
type(job_id)
# Out:
# float

# %% [markdown]
# #Strings

# %%
skill='Pyhton'

# %%
skill.upper()
# Out:
# 'PYHTON'

# %%
skill.lower()
# Out:
# 'pyhton'

# %%
skill.replace('P','J')
# Out:
# 'Jyhton'

# %%
job_title='Data Analyst'

# %%
job_title=job_title.replace('a','o',1)\

# %%
job_title.split(sep=' ',maxsplit=1)
# Out:
# ['Doto', 'Analyst']
