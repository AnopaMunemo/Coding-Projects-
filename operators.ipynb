# %% [markdown]
# <a href="https://colab.research.google.com/github/AnopaMunemo/Coding-Projects-/blob/main/operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
job_work_from_home = True
job_health_insurance= False
job_no_degree_mention= True

job_health_insurance or job_no_degree_mention
# Out:
# True

# %%
if job_health_insurance or job_work_from_home or not job_no_degree_mention :
  print('Meets requirements')
# Out:
# Meets requirements

# %%
'Data' in 'Data analyst'
# Out:
# True

# %%
job_skills = ['pyhton' , 'r' ,'sql']

# %%
'pyhton' in job_skills
# Out:
# True
