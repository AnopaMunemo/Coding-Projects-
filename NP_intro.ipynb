# %% [markdown]
# <a href="https://colab.research.google.com/github/AnopaMunemo/Coding-Projects-/blob/main/NP_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import my_module

my_module.skill_list
# Out:
# ['Python', 'SQL', 'Excel']

# %%
my_module.skill('Python')
# Out:
# 'Pythonis my favourite skill!'

# %%
import random

salary_list=[random.randint(50000,100000) for _ in range(1_000_000)]

# %%
import statistics

# %%
# %%timeit
statistics.mean(salary_list)
# Out:
# 266 ms ± 11.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import numpy as np

# %%
# %%timeit
np.mean(salary_list)
# Out:
# 63.4 ms ± 6.99 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
my_array=np.array([1,2,3,4])

# %%
import numpy as np

# %%
# Job titles
job_titles = np.array([
    "Data Analyst",
    "Data Scientist",
    "Data Engineer",
    "Machine Learning Engineer",'AI Engineer'
])


base_salaries = np.array([
    350000,
    550000,
    650000,
    750000,np.nan
])

# Bonus rates
bonus_rates = np.array([
    0.05,
    0.10,
    0.12,
    0.15,np.nan
])

# %%
total_salary = base_salaries * (1+bonus_rates)

total_salary
# Out:
# array([367500., 605000., 728000., 862500.,     nan])

# %%
np.nanmean(total_salary)
# Out:
# np.float64(640750.0)
